# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb
from glob import glob

# %%
feed_survey = pd.read_csv('datasets/SA Feedback Surveys_FINAL/2017/Student Feedback Surveys-Superview.csv')
feed_survey
# Out:
#         ID       Location            Track    Week Rating (Num)  \
# 0      134  San Francisco   Apps, Explorer  Week 1            3
# 1       36    Los Angeles             Apps  Week 1            4
# 2      117  San Francisco            Games  Week 1            4
# 3      253            NaN              NaN  Week 2            4
# 4      350  New York City   Apps, Explorer  Week 1            4
# 5       23   Redwood City             Apps  Week 1            5
# 6       28    Los Angeles             Apps  Week 7            5
# 7       65  San Francisco             Apps  Week 1            5
# 8      101    Santa Clara             Apps  Week 1            5
# 9      124    Santa Clara             Apps  Week 1            5
# 10     157   Redwood City             Apps  Week 2            5
# 11     170        Oakland             Apps  Week 2            5
# 12     255  San Francisco             Apps  Week 2            5
# 13     289  Washington DC             Apps  Week 1            5
# ...

# %%
#CLEANING DATA
#Got rid of all the NaN
    #The NaN has a tool will only be usefull when comparing how through time the rating and perceived pace relate
    
#Comparison on how the different tracks are perceived different by the students, depending on the place, do not 
#do not differentiate explorers
#Extract explorers and compare
#Just leave the explorers and compare
#Connect how the rating (1-10) affects the perceived pace, through time
#Change of rating through the weeks
#Change of schedule pacing compared 

#Transform weeks to just INT
#Transform Way too slow to 1 | A little too slow to 2 | Just right to 3 | A little too fast to 4 | Way too fast to 5
#How this translates

#over_15_fare_over_30_age = len(titanic_df[(titanic_df['Fare'] >= 15) & (titanic_df['Age'] >= 30)])

# %%
#There should be a function that tells me all the different possible values that I can find in a dataset.row

#Gets me the dataframe without NaN values, useful for comparison
#between week and rating evolution
def clean_feed_survey(dataset):
    return dataset[dataset["Location"].notnull()]

clean_text = clean_feed_survey(feed_survey)
clean_text

#This should get me only a specificil location
#def get_location(place ,row)
 #   #conditional statement than identifies the location and return a 
  #  #dataframe 
   # place = []
    #Location = row["Location"].lower()
    #
    #if place in Location:
     #   location.append()
    
#Compare how the rating relates to the perception of "Schedule Pacing"
def convert_schedule_pacing(df):
    pacing_key = {"Way too slow": 1, "A little too slow": 2, "Just right": 3, "A little too fast": 4, "Way too fast": 5}
    df["Schedule Pacing"] = df["Schedule Pacing"].map(pacing_key)     
    return df

new_clean_text = convert_schedule_pacing(clean_text)

def convert_weeks_to_nums(df):
    weeks_key = dict()
    
    for num in range(1, 9):
        weeks_key["Week {}".format(num)] = num
        
    df["Week"] = df["Week"].map(weeks_key)
    return df
    
convert_weeks_to_nums(new_clean_text)

# clean_feed_survey = clean_feed_survey(feed_survey)
# #First I need to get just the column
# week_row = len(feed_survey[(feed_survey['Week'])])

# #Second I need to move everyday weekday into an array, iterate 
#through it and change to int

# #should get only the needed to row and change it to int
# def change_strweek_to_intweek(dataset):
#     dataset = int(dataset)
#     return dataset

# def change_strpacing_to_intpacing(dataset):
#     return dataset

# # feed_survey_all_pacing_int = 

# # feed_survey_all_week_int = 

# # feed_survey_all_int =
# Out:
# {'Week 1': 1, 'Week 2': 2, 'Week 3': 3, 'Week 4': 4, 'Week 5': 5, 'Week 6': 6, 'Week 7': 7, 'Week 8': 8}
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         ID       Location            Track  Week Rating (Num)  Schedule Pacing
# 0      134  San Francisco   Apps, Explorer     1            3                3
# ...
